# %% [markdown]
# <a href="https://colab.research.google.com/github/sweetiepickle/AI-17-4-23-mtcnn/blob/main/AI_17_4_23_mtcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mctcnn : multi task cascaded cnn
# facenet
# resnet
# vgg16
# r_cnn
# faster_rcnn
# yolo

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 29.3 MB/s eta 0:00:00
# ...

# %%
from matplotlib import pyplot as plt
from mtcnn import MTCNN
filename = '/content/GenG.jpg'
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces :
  print (face)
# Out:
# ...
# 2/2 [==============================] - 0s 15ms/step
# {'box': [211, 20, 26, 30], 'confidence': 0.9999995827674866, 'keypoints': {'left_eye': (215, 30), 'right_eye': (224, 30), 'nose': (215, 37), 'mouth_left': (214, 43), 'mouth_right': (221, 44)}}
# {'box': [276, 35, 26, 30], 'confidence': 0.9998705387115479, 'keypoints': {'left_eye': (279, 46), 'right_eye': (288, 43), 'nose': (280, 52), 'mouth_left': (281, 59), 'mouth_right': (289, 57)}}
# {'box': [114, 48, 25, 29], 'confidence': 0.9994749426841736, 'keypoints': {'left_eye': (118, 57), 'right_eye': (128, 55), 'nose': (121, 63), 'mouth_left': (120, 70), 'mouth_right': (129, 68)}}
# {'box': [395, 42, 25, 32], 'confidence': 0.998584508895874, 'keypoints': {'left_eye': (399, 52), 'right_eye': (410, 52), 'nose': (401, 58), 'mouth_left': (398, 66), 'mouth_right': (406, 66)}}
# ...

# %%
from matplotlib import pyplot as plt
from mtcnn import MTCNN
filename = '/content/real 1718.jpg'
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
ax = plt.gca()
for face in faces:
  x, y, width, height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color ='red')
  ax.add_patch(rect)
  #plt.savefig('/content/real 1718.jpg')
plt.show()
#plt.axis('off')
# Out:
# ...
# 7/7 [==============================] - 0s 40ms/step

# %%
from matplotlib import pyplot as plt
from mtcnn import MTCNN
filename = '/content/real 1718.jpg'
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
ax = plt.gca()
for face in faces:
  x, y, width, height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color ='red')
  ax.add_patch(rect)
  for key, value in face['keypoints'].items():
    dot= plt.Circle(value, radius = 2 , color = 'red')
    ax.add_patch(dot)
  #plt.savefig('/content/real 1718.jpg')
plt.show()
#plt.axis('off')
# Out:
# ...
# 7/7 [==============================] - 0s 39ms/step
# {'box': [351, 353, 25, 37], 'confidence': 0.9999988675117493, 'keypoints': {'left_eye': (358, 366), 'right_eye': (369, 365), 'nose': (363, 372), 'mouth_left': (359, 380), 'mouth_right': (368, 379)}}
# {'box': [277, 462, 24, 40], 'confidence': 0.9999982714653015, 'keypoints': {'left_eye': (292, 478), 'right_eye': (297, 476), 'nose': (300, 484), 'mouth_left': (293, 491), 'mouth_right': (298, 490)}}
# {'box': [244, 298, 24, 36], 'confidence': 0.9999932646751404, 'keypoints': {'left_eye': (250, 311), 'right_eye': (262, 310), 'nose': (257, 316), 'mouth_left': (252, 325), 'mouth_right': (262, 325)}}
# {'box': [380, 273, 26, 37], 'confidence': 0.9999896883964539, 'keypoints': {'left_eye': (386, 284), 'right_eye': (398, 284), 'nose': (393, 289), 'mouth_left': (388, 298), 'mouth_right': (398, 297)}}
# ...

# %%
from matplotlib import pyplot as plt
from mtcnn import MTCNN
mask = '/content/mask.jpg'
img = plt.imread(mask)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
ax = plt.gca()
for face in faces:
  x, y, width, height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color ='red')
  ax.add_patch(rect)
  for key, value in face['keypoints'].items():
    dot= plt.Circle(value, radius = 2 , color = 'red')
    ax.add_patch(dot)
  #plt.savefig('/content/real 1718.jpg')
  print(faces)
plt.show()
#plt.axis('off')
# Out:
# ...
# 1/1 [==============================] - 0s 195ms/step
# ...

# %%
from matplotlib import pyplot as plt
from mtcnn import MTCNN

def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i  in range (len(result_list)):
    x1 , y1 , width , height = result_list[i]['box']
    x2 , y2 = x1 + width , y1 + height
    plt.subplot(1, len(result_list), i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2, x1:x2])
    plt.savefig(f'gen{i+1}.jpg')
    plt.clf()
  plt.show()

filename = '/content/GenG.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename, faces)
# Out:
# ...
# 2/2 [==============================] - 0s 12ms/step

# %%
pip install keras_resnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for keras_resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20484 sha256=53457fb4623076af6ee9d9e5a73a8ff4c34adea2587ff9940808c6a61a800e67
#   Stored in directory: /root/.cache/pip/wheels/53/ed/ef/144804f160c278c80d6429c97ed126b61276721894ce64cccc
# Successfully built keras_resnet
# ...

# %%
from matplotlib import pyplot as plt
from mtcnn import MTCNN
from keras.utils import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/cats.jpg'
img = load_img(img_path, target_size=(224,224))
x = img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
img = plt.imread(img_path)
plt.show()

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n02124075', 'Egyptian_cat', 0.48861167), ('n02123045', 'tabby', 0.29824483), ('n02123394', 'Persian_cat', 0.05925068)]
